# %% [markdown]
# # 5장. 선형 회귀 모델: 먼저 긋고 수정하기

# %% [markdown]
# [<img src="https://raw.githubusercontent.com/taehojo/taehojo.github.io/master/assets/images/linktocolab.png" align="left"/> ](https://colab.research.google.com/github/taehojo/deeplearning/blob/master/colab/ch05-colab.ipynb)

# %% [markdown]
# ## 2. 파이썬 코딩으로 확인하는 선형 회귀

# %% [markdown]
# ### 1.환경 준비

# %%
#matplotlib 라이브러리를 설치합니다.
# !pip install matplotlib
# Out:
#   Cell In[1], line 2
#     pip install matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# matplotlib.pyplot 모듈을 plt라는 이름으로 가져온다.
# matplotlib.pyplot는 데이터 시각화를 위해 사용되는 matplotlib 라이브러리의 하위 모듈이다.
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. 데이터 준비

# %%
#공부 시간 X와 성적 Y의 넘파이 배열을 만듭니다.
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# ### 3. 데이터 분포 확인

# %%
# 데이터의 분포를 그래프로 나타냅니다.
# plt.scatter() 함수를 사용하여 2D 산점도 그래프를 생성한다. x는 x축에 해당하는 데이터를 나타내는 NumPy배열이고, y는 y축에 해당하는 데이터를 나타내는 NumPy배열이다.
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### 4. 실행을 위한 변수 설정

# %%
# 기울기 a와 절편 b의 값을 초기화합니다.
a = 0
b = 0

#학습률을 정합니다.
# lr은 learning rate의 약자이다.
# 학습률은 모델이 데이터에서 학습할 때 가중치를 조정하는 속도를 결정한다.
lr = 0.03

#몇 번 반복될지를 설정합니다. 
epochs = 2001

# %% [markdown]
# ### 5. 경사 하강법

# %%
# x 값이 총 몇 개인지 셉니다.
n=len(x)

#경사 하강법을 시작합니다.
for i in range(epochs):                  # epoch 수 만큼 반복
    
    y_pred = a * x + b                   # 예측 값을 구하는 식입니다. 
    error = y - y_pred                   # 실제 값과 비교한 오차를 error로 놓습니다.
    
    a_diff = (2/n) * sum(-x * (error))   # 오차 함수를 a로 편미분한 값입니다. 
    b_diff = (2/n) * sum(-(error))       # 오차 함수를 b로 편미분한 값입니다. 
    
    a = a - lr * a_diff     # 학습률을 곱해 기존의 a 값을 업데이트합니다.
    b = b - lr * b_diff     # 학습률을 곱해 기존의 b 값을 업데이트합니다.
    
    if i % 100 == 0:        # 100번 반복될 때마다 현재의 a 값, b 값을 출력합니다.
        print("epoch=%.f, 기울기=%.04f, 절편=%.04f" % (i, a, b))
# Out:
# epoch=0, 기울기=27.8400, 절편=5.4300
# epoch=100, 기울기=7.0739, 절편=50.5117
# epoch=200, 기울기=4.0960, 절편=68.2822
# epoch=300, 기울기=2.9757, 절편=74.9678
# epoch=400, 기울기=2.5542, 절편=77.4830
# epoch=500, 기울기=2.3956, 절편=78.4293
# epoch=600, 기울기=2.3360, 절편=78.7853
# epoch=700, 기울기=2.3135, 절편=78.9192
# epoch=800, 기울기=2.3051, 절편=78.9696
# epoch=900, 기울기=2.3019, 절편=78.9886
# epoch=1000, 기울기=2.3007, 절편=78.9957
# epoch=1100, 기울기=2.3003, 절편=78.9984
# epoch=1200, 기울기=2.3001, 절편=78.9994
# epoch=1300, 기울기=2.3000, 절편=78.9998
# epoch=1400, 기울기=2.3000, 절편=78.9999
# epoch=1500, 기울기=2.3000, 절편=79.0000
# epoch=1600, 기울기=2.3000, 절편=79.0000
# epoch=1700, 기울기=2.3000, 절편=79.0000
# epoch=1800, 기울기=2.3000, 절편=79.0000
# epoch=1900, 기울기=2.3000, 절편=79.0000
# epoch=2000, 기울기=2.3000, 절편=79.0000

# %% [markdown]
# ### 6. 그래프 확인

# %%
#앞서 구한 최종 a값을 기울기, b값을 y절편에 대입하여 그래프를 그립니다.
y_pred = a * x + b      

#그래프 출력
plt.scatter(x, y)   #입력 데이터(x, y)를 산점도로 그린다.
plt.plot(x, y_pred,'r') # plt.plot() 함수를 사용하여 입력 데이터(x)와 예측값(y_pred)을 연결하는 선 그래프를 그린다. 'r'은 선의 색상을 나타내며, 여기서는 빨간색을 의미한다.
plt.show()

# %% [markdown]
# ## 4. 파이썬 코딩으로 확인하는 다중 선형 회귀

# %% [markdown]
# ### 1.환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. 데이터 준비

# %%
#공부 시간 x1과 과외 시간 x2, 그성적 y의 넘파이 배열을 만듭니다. 
x1 = np.array([2, 4, 6, 8])
x2 = np.array([0, 4, 2, 3])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# ### 3. 데이터 분포 확인

# %%
# 데이터의 분포를 그래프로 나타냅니다.
# plt.figure() 함수를 사용하여 새로운 Figure 객체 fig를 생성한다.
# ax(Axes) 좌표 축을 뜻한다.
# fig.add_subplot() 메서드를 사용하여 3D 서브플롯 ax를 fig에 추가한다. projection='3d' 매개변수를 사용하여 3D 그래프를 생성한다.
# 111은 서브플롯의 위치를 지정하는 값이다.
# 첫 번째 숫자: 서브플롯의 행(row) 개수를 나타낸다.
# 두 번째 숫자: 서브플롯의 열(column) 개수를 나타낸다.
# 세 번째 숫자: 현재 서브플롯의 위치를 나타낸다.
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(x1, x2, y) 
plt.show()

# %% [markdown]
# ### 4. 실행을 위한 변수 설정

# %%
# 기울기 a와 절편 b의 값을 초기화합니다.
a1 = 0
a2 = 0
b = 0

#학습률을 정합니다.
lr = 0.01

#몇 번 반복될지를 설정합니다.
epochs = 2001

# %% [markdown]
# ### 5. 경사 하강법

# %%
# x 값이 총 몇 개인지 셉니다. x1과 x2의 수가 같으므로 x1만 세겠습니다. 
n=len(x1)   # 변수의 총 개수

#경사 하강법을 시작합니다.
for i in range(epochs):                  # epoch 수 만큼 반복
    
    y_pred = a1 * x1 + a2 * x2 + b       #예측 값을 구하는 식을 세웁니다
    error = y - y_pred                   #실제 값과 비교한 오차를 error로 놓습니다.
    
    a1_diff = (2/n) * sum(-x1 * (error)) # 오차함수를 a1로 편미분한 값입니다. 
    a2_diff = (2/n) * sum(-x2 * (error)) # 오차함수를 a2로 편미분한 값입니다. 
    b_diff = (2/n) * sum(-(error))       # 오차함수를 b로 편미분한 값입니다. 
    
    a1 = a1 - lr * a1_diff  # 학습률을 곱해 기존의 a1 값을 업데이트합니다.  / 학습률(lr)을 기울기(a1)의 변화율(a1_diff)에 곱한 값만큼 기존의 a1 값을 업데이트
    a2 = a2 - lr * a2_diff  # 학습률을 곱해 기존의 a2 값을 업데이트합니다.  / 학습률(lr)을 기울기(a2)의 변화율(a2_diff)에 곱한 값만큼 기존의 a2 값을 업데이트
    b = b - lr * b_diff     # 학습률을 곱해 기존의 b 값을 업데이트합니다.   / 학습률(lr)을 절편(b)의 변화율(b_diff)에 곱한 값만큼 기존의 b 값을 업데이트
    
    if i % 100 == 0:        # 100번 반복될 때마다 현재의 a1, a2, b 값을 출력합니다.
        print("epoch=%.f, 기울기1=%.04f, 기울기2=%.04f, 절편=%.04f" % (i, a1, a2, b))
# Out:
# epoch=0, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8569
# epoch=100, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8570
# epoch=200, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8570
# epoch=300, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=400, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=500, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=600, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=700, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=800, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=900, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1000, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1100, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1200, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1300, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1400, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1500, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1600, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1700, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=1800, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# ...

# %%
#실제 점수와 예측 된 점수를 출력합니다.
print("실제 점수:", y)
print("예측 점수:", y_pred)
# Out:
# 실제 점수: [81 93 91 97]
# 예측 점수: [80.85714258 92.99999991 91.42857142 96.71428584]

# %% [markdown]
# ## 5-1. 텐서플로에서 실행하는 선형 회귀 모델

# %% [markdown]
# ### 1.환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt

#텐서플로의 케라스 API에서 필요한 함수들을 불러 옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 2. 데이터 준비

# %%
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# ### 3. 모델 실행

# %%
model = Sequential() 

# 출력 값, 입력 변수, 분석 방법에 맞게끔 모델을 설정합니다. 
# activation='linear'는 선형 활성화 함수를 의미한다. 선형 활성화 함수는 회귀 문제에서 사용되는데, 입력과 가중치의 선형 조합으로 출력을 계산하는 함수이다.
# 회귀 분석은 주어진 데이터를 기반으로 입력 변수와 출력 변수 간의 함수적인 관계를 파악하고, 이를 사용하여 새로운 입력 값에 대한 출력 값을 예측하는 작업을 수행한다. ex) 주택 가격 예측, 주식 가격 예측 등 연속적인 수치 값을 예측하는 문제에 사용
model.add(Dense(1, input_dim=1, activation='linear'))

# 오차 수정을 위해 경사 하강법(sgd)을, 오차의 정도를 판단하기 위해 평균 제곱 오차(mse)를 사용합니다. 
# 최적화 알고리즘으로 확률적 경사 하강법(Stochastic Gradient Descent)를 사용한다. 가중치를 업데이트하는데 사용되는 알고리즘으로, 손실 함수의 그래디언트를 계산하여 가중치를 조정한다. 
# SGD는 매개변수로 학습률(learning rate)을 설정할 수 있으며, 디폴트 값은 0.01이다.
model.compile(optimizer='sgd', loss='mse')

# 오차를 최소화하는 과정을 2000번 반복합니다.
model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 655ms/step - loss: 8761.4141
# Epoch 2/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 2117.1362
# Epoch 3/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1135.9275
# Epoch 4/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 986.5164
# Epoch 5/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 959.3102
# Epoch 6/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 950.0867
# Epoch 7/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 943.5385
# Epoch 8/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 937.4166
# Epoch 9/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 931.3907
# Epoch 10/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 925.4124
# Epoch 11/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 919.4739
# Epoch 12/2000
# ...

# %% [markdown]
# ### 4. 그래프로 확인

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x),'r')    # 예측 결과를 그래프로 나타냅니다.
plt.show()
# Out:
# 1/1 [==============================] - 0s 231ms/step

# %% [markdown]
# ### 5. 모델 테스트

# %%
#임의의 시간을 집어넣어 점수를 예측하는 모델을 테스트해 보겠습니다.
# hour 변수에 예측하고자 하는 시간을 할당한다.
# predict() 메서드를 사용하여 모델에 입력 데이터를 전달하고, 해당 입력에 대한 예측 값을 얻는다.
# 입력은 대괄호([])로 묶어야 하며, 여러 개의 입력을 예측하려면 입력을 리스트로 전달해야 한다.
hour = 7    
prediction = model.predict([hour])

print("%.f시간을 공부할 경우의 예상 점수는 %.02f점입니다" % (hour, prediction))
# Out:
# 1/1 [==============================] - 0s 155ms/step
# 7시간을 공부할 경우의 예상 점수는 95.12점입니다

# %% [markdown]
# ## 5-2 텐서플로에서 실행하는 다중 선형회귀 모델

# %% [markdown]
# ### 1.환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt

#텐서플로의 케라스 API에서 필요한 함수들을 불러 옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 2. 데이터 준비

# %%
x = np.array([[2, 0], [4, 4], [6, 2], [8, 3]])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# ### 3. 모델 실행

# %%
model = Sequential()

#입력 변수가 2개(학습 시간, 과외 시간)이므로 input_dim에 2를 입력합니다. 
model.add(Dense(1, input_dim=2, activation='linear'))
model.compile(optimizer='sgd' ,loss='mse')

model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 119ms/step - loss: 8184.9204
# Epoch 2/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 1435.6133
# Epoch 3/2000
# 1/1 [==============================] - 0s 999us/step - loss: 955.4879
# Epoch 4/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 916.3068
# Epoch 5/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 908.1718
# Epoch 6/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 902.2542
# Epoch 7/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 896.5266
# Epoch 8/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 890.8461
# Epoch 9/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 885.2023
# Epoch 10/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 879.5942
# Epoch 11/2000
# 1/1 [==============================] - 0s 1ms/step - loss: 874.0219
# Epoch 12/2000
# ...

# %% [markdown]
# ### 4. 모델 테스트

# %%
#임의의 학습 시간과 과외 시간을 집어넣어 점수를 예측하는 모델을 테스트해 보겠습니다.

hour = 7
private_class = 4
prediction = model.predict([[hour, private_class]])

print("%.f시간을 공부하고 %.f시간의 과외를 받을 경우, 예상 점수는 %.02f점입니다" % (hour, private_class, prediction))
# Out:
# 7시간을 공부하고 4시간의 과외를 받을 경우, 예상 점수는 97.53점입니다
